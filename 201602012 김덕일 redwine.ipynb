# %%
from keras.models import Sequential
from keras.layers.core import Dense
from keras.utils import np_utils
from sklearn.preprocessing import LabelEncoder

import pandas as pd 
import numpy
import tensorflow as tf

#시드값
seed = 0
numpy.random.seed(seed)
tf.random.set_seed(seed)

#//데이터 -> red->결과값 3~8 red1 -> 결과값1~10
df = pd.read_csv("winequality-red.csv", delimiter=";")

#데이터 분류
dataset = df.values
X = dataset[:, 0:11].astype(float)
Y_obj = dataset[:, 11]

#원 핫 인코딩
e = LabelEncoder()
e.fit(Y_obj)
Y = e.transform(Y_obj)
Y_encoded = tf.keras.utils.to_categorical(Y)

#모델 설정 red -> 6, red1 -> 10 
model = Sequential()
model.add(Dense(16, input_dim=11, activation="relu"))
model.add(Dense(10, activation="relu"))
model.add(Dense(6, activation="softmax"))

#컴파일
model.compile(loss="categorical_crossentropy", optimizer="adam",metrics=["accuracy"])

#실행
model.fit(X, Y_encoded, epochs=50, batch_size=2)

#결과
print("\n Accuracy: %.4f" % (model.evaluate(X, Y_encoded)[1]))
# Out:
# Epoch 1/50
# 800/800 [==============================] - 1s 1ms/step - loss: 1.4778 - accuracy: 0.4067
# Epoch 2/50
# 800/800 [==============================] - 1s 1ms/step - loss: 1.1504 - accuracy: 0.5005
# Epoch 3/50
# 800/800 [==============================] - 1s 1ms/step - loss: 1.1660 - accuracy: 0.4654
# Epoch 4/50
# 800/800 [==============================] - 1s 1ms/step - loss: 1.1621 - accuracy: 0.5058
# Epoch 5/50
# 800/800 [==============================] - 1s 1ms/step - loss: 1.1364 - accuracy: 0.5088
# Epoch 6/50
# 800/800 [==============================] - 1s 1ms/step - loss: 1.1193 - accuracy: 0.5232
# Epoch 7/50
# 800/800 [==============================] - 1s 1ms/step - loss: 1.1457 - accuracy: 0.5123
# Epoch 8/50
# 800/800 [==============================] - 1s 1ms/step - loss: 1.0951 - accuracy: 0.5203
# Epoch 9/50
# 800/800 [==============================] - 1s 1ms/step - loss: 1.0985 - accuracy: 0.5009
# Epoch 10/50
# 800/800 [==============================] - 1s 1ms/step - loss: 1.0843 - accuracy: 0.5311
# Epoch 11/50
# 800/800 [==============================] - 1s 1ms/step - loss: 1.0700 - accuracy: 0.5319
# Epoch 12/50
# 800/800 [==============================] - 1s 1ms/step - loss: 1.0612 - accuracy: 0.5471
# Epoch 13/50
# 800/800 [==============================] - 1s 1ms/step - loss: 1.0704 - accuracy: 0.5428
# Epoch 14/50
# 800/800 [==============================] - 1s 1ms/step - loss: 1.0626 - accuracy: 0.5451
# Epoch 15/50
# 800/800 [==============================] - 1s 1ms/step - loss: 1.0408 - accuracy: 0.5674
# Epoch 16/50
# 800/800 [==============================] - 1s 1ms/step - loss: 1.0118 - accuracy: 0.5618
# Epoch 17/50
# 800/800 [==============================] - 1s 1ms/step - loss: 1.0266 - accuracy: 0.5559
# Epoch 18/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.9987 - accuracy: 0.5766
# Epoch 19/50
# 800/800 [==============================] - 1s 1ms/step - loss: 1.0102 - accuracy: 0.5518
# Epoch 20/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.9850 - accuracy: 0.5692
# Epoch 21/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.9819 - accuracy: 0.5867
# Epoch 22/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.9640 - accuracy: 0.5906
# Epoch 23/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.9786 - accuracy: 0.5859
# Epoch 24/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.9607 - accuracy: 0.6128
# Epoch 25/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.9351 - accuracy: 0.5917
# Epoch 26/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.9707 - accuracy: 0.5792
# Epoch 27/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.9754 - accuracy: 0.5607
# Epoch 28/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.9474 - accuracy: 0.5842
# Epoch 29/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.9848 - accuracy: 0.5819
# Epoch 30/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.9783 - accuracy: 0.5662
# Epoch 31/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.9677 - accuracy: 0.5900
# Epoch 32/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.9667 - accuracy: 0.5774
# Epoch 33/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.9404 - accuracy: 0.5970
# Epoch 34/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.9528 - accuracy: 0.5782
# Epoch 35/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.9299 - accuracy: 0.5792
# Epoch 36/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.9532 - accuracy: 0.5830
# Epoch 37/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.9188 - accuracy: 0.6041
# Epoch 38/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.9228 - accuracy: 0.6059
# Epoch 39/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.9330 - accuracy: 0.5836
# Epoch 40/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.9240 - accuracy: 0.5979
# Epoch 41/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.9514 - accuracy: 0.5932
# Epoch 42/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.9359 - accuracy: 0.5872
# Epoch 43/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.8741 - accuracy: 0.6186
# Epoch 44/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.9382 - accuracy: 0.5968
# Epoch 45/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.9637 - accuracy: 0.5642
# Epoch 46/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.9364 - accuracy: 0.5847
# Epoch 47/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.8959 - accuracy: 0.6103
# Epoch 48/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.9277 - accuracy: 0.6008
# Epoch 49/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.9391 - accuracy: 0.5786
# Epoch 50/50
# 800/800 [==============================] - 1s 1ms/step - loss: 0.9586 - accuracy: 0.5877
# 50/50 [==============================] - 0s 950us/step - loss: 0.9194 - accuracy: 0.6004
#
#  Accuracy: 0.6004

# %%
~
